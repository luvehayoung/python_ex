# %% [markdown]
# # 간단한 요청

# %%
import requests

# %%
response = requests.get("http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=016&aid=0001338335&date=20180109&type=1&rankingSeq=1&rankingSectionId=100")

# %%
html = response.text

# %%
print(html)
# Out:
# <!DOCTYPE HTML>
# <html lang="ko">
# <head>
# <meta charset="euc-kr">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <meta name="viewport" content="width=1023" />
# <title>“회담실황, 확 드러내놓자” 단연 눈에 띈 ‘리선권式 화법’ : 네이버 뉴스</title>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <meta property="me2:post_tag"		content="헤럴드경제 : 네이버뉴스"/>
# <meta property="me2:category1"		content="헤럴드경제"/>
# <meta property="me2:category2"		content="기타 기사"/>
# <meta property="me2:image"			content="http://imgnews.naver.net/image/origin/016/2018/01/09/1338335.jpg"/>
#
# <meta property="og:title"			content="“회담실황, 확 드러내놓자” 단연 눈에 띈 ‘리선권式 화법’"/>
# <meta property="og:type"			content="article"/>
# <meta property="og:url"				content="http://news.naver.com/main/read.nhn?mode=LSD&mid=sec&oid=016&aid=0001338335&sid1=001"/>
# <meta property="og:image"			content="http://imgnews.naver.net/image/origin/016/2018/01/09/1338335.jpg"/>
# ...

# %%
import requests # pip install requests

# GET 요청
response = requests.get('https://gurneykim.github.io/ex_ipython/')
"""
requests.get('https://gurneykim.github.io/ex_ipython/') 
 -> 지정한 주소 서버에 get 요청을 했다.
 
response = requests.get('https://gurneykim.github.io/ex_ipython/')
-> 지정한 주소의 서버가 get 요청을 받은 후 응답했다.
응답 패킷을 response 변수에 넣었다.
"""

# response 변수에 들어있는 응답 패킷 중 html 소스확인 .text
html = response.text

# https://gurneykim.github.io/ex_ipython/ - 페이지 소스보기 의 html 파일과 똑같다.
# 개발자 도구의 html 파일은 변화하는 소스까지 있다.

# %%
print(html)
# Out:
# <!DOCTYPE html>
# <html>
# <head><meta charset="utf-8" />
# <title>신생아 이름 분석</title><script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.1.10/require.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery/2.0.3/jquery.min.js"></script>
#
# <style type="text/css">
#     /*!
# *
# * Twitter Bootstrap
# *
# */
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
#  */
# /*! normalize.css v3.0.3 | MIT License | github.com/necolas/normalize.css */
# html {
#   font-family: sans-serif;
#   -ms-text-size-adjust: 100%;
#   -webkit-text-size-adjust: 100%;
# }
# body {
#   margin: 0;
# }
# article,
# aside,
# details,
# figcaption,
# figure,
# footer,
# header,
# hgroup,
# main,
# menu,
# nav,
# section,
# summary {
#   display: block;
# }
# audio,
# canvas,
# progress,
# video {
#   display: inline-block;
#   vertical-align: baseline;
# }
# ...

# %% [markdown]
# 요청 패킷 예
#
# GET / ex_ipython/ HTTP/1.1
# Host: gurneykim.github.io/
# Connection: keep-alive
# Accept: */*
# User-Agent: python-requests/2.14.2
# Accept-Encoding: gzip, deflate
# (빈줄)
# (Body 없음)
#
#
# key : values 형식으로 자료를 준다.

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? ㅛ
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %% [markdown]
# # 웹툰 크롤링

# %%
# requests 패키지 로드
import requests
import os

# %%
image_urls =[]

for i in range(1,23):
    image_urls.append("http://imgcomic.naver.net/webtoon/650304/141/20180108170013_52d65e4f4608f1d37b915ccabdb38163_IMAG01_{}.jpg"
                      .format(i))
    
for image_url in image_urls:
    headers = {
        'Referer' : "http://comic.naver.com/webtoon/list.nhn?titleId=650304&weekday="}
#    response = requests.get(image_url)
    #headers는 함수 인자
    response = requests.get(image_url,headers=headers)
    
    image_data = response.content #img데이터만
    #.content Raw data, byte 타입 가져오기 / .text : Raw Data에 대해 서버 응답의 content-type 인코딩으로 디코딩을을 시도한 유니코드 문자열
    filename = os.path.basename(image_url)
    with open(filename, 'wb') as f:
        print('writing to {} ({} bytes)'.format(filename, len(image_data)))
        f.write(image_data)
# Out:
# writing to 20180108170013_52d65e4f4608f1d37b915ccabdb38163_IMAG01_1.jpg (164784 bytes)
# writing to 20180108170013_52d65e4f4608f1d37b915ccabdb38163_IMAG01_2.jpg (235975 bytes)
# writing to 20180108170013_52d65e4f4608f1d37b915ccabdb38163_IMAG01_3.jpg (180863 bytes)
# writing to 20180108170013_52d65e4f4608f1d37b915ccabdb38163_IMAG01_4.jpg (242409 bytes)
# writing to 20180108170013_52d65e4f4608f1d37b915ccabdb38163_IMAG01_5.jpg (183157 bytes)
# writing to 20180108170013_52d65e4f4608f1d37b915ccabdb38163_IMAG01_6.jpg (169710 bytes)
# writing to 20180108170013_52d65e4f4608f1d37b915ccabdb38163_IMAG01_7.jpg (228061 bytes)
# writing to 20180108170013_52d65e4f4608f1d37b915ccabdb38163_IMAG01_8.jpg (196103 bytes)
# writing to 20180108170013_52d65e4f4608f1d37b915ccabdb38163_IMAG01_9.jpg (261234 bytes)
# writing to 20180108170013_52d65e4f4608f1d37b915ccabdb38163_IMAG01_10.jpg (214070 bytes)
# writing to 20180108170013_52d65e4f4608f1d37b915ccabdb38163_IMAG01_11.jpg (191339 bytes)
# ...

# %% [markdown]
# robots.txt로 확인

# %% [markdown]
# # 네이버 웹툰

# %%
import os
import requests
# URL 소스 : http://comic.naver.com/webtoon/detail.nhn?titleId=119874&no=1015&weekday=tue
# - 덴마. 3-12화 1. 다이크(12)

image_urls = [
 'http://imgcomic.naver.net/webtoon/119874/1015/20170528204207_6e9df8e618b97520233bbb35e7d4eaaf_IMAG01_1.jpg',
 'http://imgcomic.naver.net/webtoon/119874/1015/20170528204207_6e9df8e618b97520233bbb35e7d4eaaf_IMAG01_2.jpg',
 'http://imgcomic.naver.net/webtoon/119874/1015/2017052820ㅈ4207_6e9df8e618b97520233bbb35e7d4eaaf_IMAG01_3.jpg',
]

for image_url in image_urls:
"""    headers = {
        'Referer' : "http://comic.naver.com/webtoon/detail.nhn?titleId=119874&no=1015&weekday=tue"
    }
"""
    response = requests.get(image_url)
#    response = requests.get(image_url,headers=headers)
    image_data = response.content 
    #.content Raw data, byte 타입 가져오기 / .text : Raw Data에 대해 서버 응답의 content-type 인코딩으로 디코딩을을 시도한 유니코드 문자열
    filename = os.path.basename(image_url)
    with open(filename, 'wb') as f:
        print('writing to {} ({} bytes)'.format(filename, len(image_data)))
        f.write(image_data)
